# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
uv add "crewai[google-genai]"
# Out:
# Resolved 173 packages in 20ms
# Audited 170 packages in 26ms
# Note: you may need to restart the kernel to use updated packages.

# %%
from crewai import LLM
import os

llm = LLM(
    model="gemini/gemini-3-flash-preview", # Use the 'gemini/' prefix for native support
    temperature=0.1,
    api_key=os.getenv("Gemini_API_Key") # Ensure this is passed or in your .env
)
llm.call("who invented meditation.")
# Out:
# 'Meditation was not "invented" by a single person. Instead, it evolved over thousands of years across different cultures. Because it is an internal mental process, its exact origins are difficult to pinpoint, but historians generally trace its roots to **Ancient India and China.**\n\nHere is a breakdown of the history and the key figures who shaped meditation:\n\n### 1. Prehistoric Origins (5,000 to 3,500 BCE)\nThe earliest evidence of meditation comes from the **Indus Valley Civilization** (in modern-day Pakistan and Northwest India). Archaeologists discovered wall art and seals depicting figures sitting in what appear to be meditative or yogic postures. This suggests that some form of meditation existed long before written records.\n\n### 2. Ancient India (1500 BCE – 500 BCE)\nThe first written accounts of meditation are found in the **Vedas**, the oldest scriptures of Hinduism. \n*   **The Upanishads:** These later Vedic texts (c. 800–500 BCE) began to describe meditation as a way
# ...

# %%
from crewai import Agent,Task,Crew
email_assistant = Agent(
    role="Email Assistant Agent",
    goal="Improve emails and make them sound professional and clear",
    backstory="A highly experienced communication expert skilled in professional email writing",
    verbose=True,
    llm=llm
)
original_email = """
hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think. thanks
"""
email_task = Task(
    description=f"""Take the following rough email and rewrite it into a professional and polished version.
    Expand abbreviations:
    '''{original_email}'''""",
    agent=email_assistant,
    expected_output="A professional written email with proper formatting and content.",
)
crew = Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True
)

result = crew.kickoff()
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 48c2ebca-abe6-453f-b167-cd5be5321f59                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...
