# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
uv add "crewai[google-genai]"
# Out:
# Resolved 173 packages in 16ms
# Audited 170 packages in 41ms
# Note: you may need to restart the kernel to use updated packages.

# %%
from crewai import LLM
import os
llm = LLM(
    model="gemini/gemini-3-flash-preview", # Use the 'gemini/' prefix for native support
    temperature=0.1,
    api_key=os.getenv("Gemini_API_Key") # Ensure this is passed or in your .env
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
    tracing=True
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: cf20ea5b-aa4d-42fb-820a-c35b819abaaf                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  ID: 079afe5a-d8ae-4c71-bd90-55cfe3a26536                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 5 interesting and recent facts about the future of electric vehicles (EVs):                           │
# │                                                                                                                 │
# │  *   **The Rise of Solid-State Batteries:** Toyota and Samsung are currently racing to commercialize            │
# │  solid-state batteries, which replace the liquid electrolyte found in current EVs with a solid material. This   │
# │  technology is expected to be a "game-changer" by 2027-2028, potentially offering a range of over 745 miles     │
# │  (1,200 km) on a single charge and a charging time of just 10 minutes.                                          │
# │  *   **Vehicle-to-Grid (V2G) Integration:** The future of EVs is not just as transportation, but as mobile      │
# │  power plants. Major manufacturers like Ford, GM, and BMW are implementing bidirectional charging, allowing     │
# │  EVs to send power back into the electrical grid or a home during peak demand. This "Vehicle-to-Grid"           │
# │  technology could help stabilize energy grids and allow EV owners to earn money by selling power back to        │
# │  utility companies.                                                                                             │
# │  *   **Sodium-Ion Battery Alternatives:** To reduce the industry's dependence on expensive and scarce minerals  │
# │  like lithium and cobalt, companies such as Northvolt and BYD are beginning to mass-produce sodium-ion          │
# │  batteries. These batteries use salt—an abundant and cheap resource—making them significantly more sustainable  │
# │  and less prone to "thermal runaway" (fire) than traditional lithium-ion cells.                                 │
# │  *   **Wireless Dynamic Charging Roads:** Several countries, including Sweden and the United States             │
# │  (specifically Detroit), have begun testing "electric roads" that charge EVs while they are in motion. Using    │
# │  inductive charging coils buried beneath the asphalt, these roads allow vehicles to top up their batteries      │
# │  while driving, which could eventually lead to smaller, lighter batteries and the total elimination of "range   │
# │  anxiety."                                                                                                      │
# │  *   **Price Parity with Gas Vehicles:** According to research from BloombergNEF and Goldman Sachs, EVs are     │
# │  expected to reach price parity with internal combustion engine (ICE) vehicles by the mid-2020s (roughly        │
# │  2025–2027) without the need for government subsidies. This is driven by the rapidly falling cost of battery    │
# │  packs, which have dropped nearly 90% in price over the last decade.                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  ID: a0d521fc-4a01-4686-8b01-e4c7933efa8e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles is shifting into high gear. By 2027, solid-state batteries from leaders like   │
# │  Toyota could deliver a 745-mile range with 10-minute charging. Beyond performance, sustainability is key;      │
# │  sodium-ion batteries are emerging as a cheaper, safer alternative to lithium. We’re also seeing EVs transform  │
# │  into mobile power plants through V2G technology, while "electric roads" in cities like Detroit test wireless   │
# │  charging on the move. With battery costs plummeting, EVs are set to reach price parity with gas cars by the    │
# │  mid-2020s, making a high-tech, emission-free future accessible to everyone.                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: cf20ea5b-aa4d-42fb-820a-c35b819abaaf                                                                       │
# │  Final Output: The future of electric vehicles is shifting into high gear. By 2027, solid-state batteries from  │
# │  leaders like Toyota could deliver a 745-mile range with 10-minute charging. Beyond performance,                │
# │  sustainability is key; sodium-ion batteries are emerging as a cheaper, safer alternative to lithium. We’re     │
# │  also seeing EVs transform into mobile power plants through V2G technology, while "electric roads" in cities    │
# │  like Detroit test wireless charging on the move. With battery costs plummeting, EVs are set to reach price     │
# │  parity with gas cars by the mid-2020s, making a high-tech, emission-free future accessible to everyone.        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# CrewOutput(raw='The future of electric vehicles is shifting into high gear. By 2027, solid-state batteries from leaders like Toyota could deliver a 745-mile range with 10-minute charging. Beyond performance, sustainability is key; sodium-ion batteries are emerging as a cheaper, safer alternative to lithium. We’re also seeing EVs transform into mobile power plants through V2G technology, while "electric roads" in cities like Detroit test wireless charging on the move. With battery costs plummeting, EVs are set to reach price parity with gas cars by the mid-2020s, making a high-tech, emission-free future accessible to everyone.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles.', name='Find 3-5 interesting and recent facts about The future of electrical vehicles.', expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw='Here are 5 interesting and recent facts about the future of electric vehicles (EVs):\n\n*   **The Rise of Solid-State Batteries:** Toyota and Samsung are currently racing to commercialize solid-state batteries, which replace the liquid electrolyte found in current EVs with a solid material. This technology is expected to be a "game-changer" by 2027-2028, potentially offering a range of over 745 miles (1,200 km) on a single charge and a charging time of just 10 minutes.\n*   **Vehicle-to-Grid (V2G) Integration:** The future of EVs is not just as transportation, but as mobile power plants. Major manufacturers like Ford, GM, and BMW are implementing bidirectional charging, allowing EVs to send power back into the electrical grid or a home during peak demand. This "Vehicle-to-Grid" technology could help stabilize energy grids and allow EV owners to earn money by selling power back to utility companies.\n*   **Sodium-Ion Battery Alternatives:** To reduce the industry\'s dependence on expensive and scarce minerals like lithium and cobalt, companies such as Northvolt and BYD are beginning to mass-produce sodium-ion batteries. These batteries use salt—an abundant and cheap resource—making them significantly more sustainable and less prone to "thermal runaway" (fire) than traditional lithium-ion cells.\n*   **Wireless Dynamic Charging Roads:** Several countries, including Sweden and the United States (specifically Detroit), have begun testing "electric roads" that charge EVs while they are in motion. Using inductive charging coils buried beneath the asphalt, these roads allow vehicles to top up their batteries while driving, which could eventually lead to smaller, lighter batteries and the total elimination of "range anxiety."\n*   **Price Parity with Gas Vehicles:** According to research from BloombergNEF and Goldman Sachs, EVs are expected to reach price parity with internal combustion engine (ICE) vehicles by the mid-2020s (roughly 2025–2027) without the need for government subsidies. This is driven by the rapidly falling cost of battery packs, which have dropped nearly 90% in price over the last decade.', pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Research Specialist. You are an expert at finding relevant and factual data.\nYour personal goal is: Research interesting facts about the topic: The future of electrical vehicles'}, {'role': 'user', 'content': '\nCurrent Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.\n\nThis is the expected criteria for your final answer: A bullet list of 3-5 facts\nyou MUST return the actual complete content as the final answer, not a summary.\n\nProvide your complete response:'}, {'role': 'assistant', 'content': 'Here are 5 interesting and recent facts about the future of electric vehicles (EVs):\n\n*   **The Rise of Solid-State Batteries:** Toyota and Samsung are currently racing to  ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
