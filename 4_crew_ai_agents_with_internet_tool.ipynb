# %%
from dotenv import load_dotenv
from pydantic import tools

load_dotenv()
# Out:
# True

# %%
from crewai import LLM
import os
llm = LLM(
    model="gemini/gemini-3-flash-preview", # Use the 'gemini/' prefix for native support
    temperature=0.1,
    api_key=os.getenv("Gemini_API_Key") # Ensure this is passed or in your .env
)

# %%
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    tools=[SerperDevTool()],
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic} as of year 2025.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d9c1f621-96b4-4e31-b100-c5a4bc97dd74                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2025.           │
# │  ID: b7941e10-fc19-4f3f-ad8b-3b0d8b38ebc3                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2025.           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  As of 2025, the electric vehicle (EV) landscape has reached several significant milestones that are reshaping  │
# │  global transportation. Here are five interesting and recent facts about the future of EVs:                     │
# │                                                                                                                 │
# │  *   **The Arrival of Mass-Produced Solid-State Batteries:** 2025 marks a pivotal year for battery technology   │
# │  as Samsung SDI and Toyota have moved from laboratory prototypes to pilot-line production of solid-state        │
# │  batteries. These batteries offer nearly double the energy density of current lithium-ion cells, promising      │
# │  ranges of over 600 miles on a single charge and the ability to recharge from 10% to 80% in approximately 9 to  │
# │  12 minutes.                                                                                                    │
# │  *   **The "Price Parity" Tipping Point:** For the first time in major markets, the manufacturing cost of       │
# │  compact and mid-sized EVs has reached parity with internal combustion engine (ICE) vehicles. This shift is     │
# │  driven by a 14% year-over-year drop in battery pack prices and the introduction of "affordable" platforms      │
# │  from manufacturers like Tesla, Volkswagen, and BYD, which have brought the entry price for high-quality EVs    │
# │  down to the $25,000 range without relying solely on government subsidies.                                      │
# │  *   **Bidirectional Charging Becomes Standard:** In 2025, Vehicle-to-Grid (V2G) and Vehicle-to-Home (V2H)      │
# │  technology has transitioned from a niche feature to a standard offering in most new EV models. This allows     │
# │  EVs to act as mobile power plants, enabling owners to power their homes during peak hours or sell excess       │
# │  energy back to the grid, effectively turning the global EV fleet into a massive distributed energy storage     │
# │  system to stabilize renewable energy fluctuations.                                                             │
# │  *   **The Rise of Sodium-Ion Batteries for Budget Models:** To reduce dependence on expensive lithium and      │
# │  cobalt, 2025 has seen the first mass-market wave of EVs powered by sodium-ion batteries. While slightly less   │
# │  energy-dense than lithium-ion, these batteries are significantly cheaper to produce and perform much better    │
# │  in extreme cold temperatures, making them the new standard for entry-level urban commuters and                 │
# │  "micro-mobility" vehicles.                                                                                     │
# │  *   **Wireless Dynamic Charging Trials:** Several major "electric highways" in Europe and the United States    │
# │  have moved past the testing phase in 2025. These roads use inductive charging coils buried beneath the         │
# │  asphalt to charge EVs while they are in motion. This technology aims to eventually reduce the size of          │
# │  batteries needed in long-haul electric trucks, as they can replenish their energy continuously while driving   │
# │  on primary freight corridors.                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2025.           │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  ID: 8d4a9a9c-001d-4ada-b9f1-1e216fb15734                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash
# Please retry in 37.523765093s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 37.523765093s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 37.523765093s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-3-flash                                                                                      │
# │  Please retry in 37.523765093s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash
# Please retry in 37.179262278s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 37.179262278s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 37.179262278s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '37s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-3-flash                                                                                      │
# │  Please retry in 37.179262278s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash
# Please retry in 36.999677989s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 36.999677989s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '36s'}]}}
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 36.999677989s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '36s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-3-flash                                                                                      │
# │  Please retry in 36.999677989s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'task_failed' closed 'agent_execution_started' (expected
# 'task_started')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'crew_kickoff_failed' closed 'agent_execution_started' (expected
# 'crew_kickoff_started')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[47], line 7
#       5 )
#       6
# ----> 7 crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/crew.py:903, in Crew.kickoff(self, inputs, input_files)
#     902 if self.process == Process.sequential:
# --> 903     result = self._run_sequential_process()
#     904 elif self.process == Process.hierarchical:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/crew.py:1334, in Crew._run_sequential_process(self)
#    1333 """Executes tasks sequentially and returns the final output."""
# -> 1334 return self._execute_tasks(self.tasks)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/crew.py:1431, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1430 context = self._get_context(task, task_outputs)
# -> 1431 task_output = task.execute_sync(
#    1432     agent=exec_data.agent,
#    1433     context=context,
#    1434     tools=exec_data.tools,
#    1435 )
#    1436 task_outputs.append(task_output)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/task.py:520, in Task.execute_sync(self, agent, context, tools)
#     519 self.start_time = datetime.datetime.now()
# --> 520 return self._execute_core(agent, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/task.py:817, in Task._execute_core(self, agent, context, tools)
#     816     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 817     raise e  # Re-raise the exception after emitting the event
#     818 finally:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/task.py:724, in Task._execute_core(self, agent, context, tools)
#     721     crewai_event_bus.emit(
#     722         self, TaskStartedEvent(context=context, task=self)
#     723     )
# --> 724 result = agent.execute_task(
#     725     task=self,
#     726     context=context,
#     727     tools=tools,
#     728 )
#     730 self._post_agent_execution(agent)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:772, in Agent.execute_task(self, task, context, tools)
#     771 except Exception as e:
# --> 772     result = self._handle_execution_error(e, task, context, tools)
#     774 return self._finalize_task_execution(task, result)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:682, in Agent._handle_execution_error(self, e, task, context, tools)
#     681 self._check_execution_error(e, task)
# --> 682 return self.execute_task(task, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:772, in Agent.execute_task(self, task, context, tools)
#     771 except Exception as e:
# --> 772     result = self._handle_execution_error(e, task, context, tools)
#     774 return self._finalize_task_execution(task, result)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:682, in Agent._handle_execution_error(self, e, task, context, tools)
#     681 self._check_execution_error(e, task)
# --> 682 return self.execute_task(task, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:772, in Agent.execute_task(self, task, context, tools)
#     771 except Exception as e:
# --> 772     result = self._handle_execution_error(e, task, context, tools)
#     774 return self._finalize_task_execution(task, result)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:681, in Agent._handle_execution_error(self, e, task, context, tools)
#     670 """Handle execution errors with retry logic (sync path).
#     671
#     672 Args:
#    (...)    679     Result from retried execution.
#     680 """
# --> 681 self._check_execution_error(e, task)
#     682 return self.execute_task(task, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:661, in Agent._check_execution_error(self, e, task)
#     653 crewai_event_bus.emit(
#     654     self,
#     655     event=AgentExecutionErrorEvent(
#    (...)    659     ),
#     660 )
# --> 661 raise e
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:759, in Agent.execute_task(self, task, context, tools)
#     758     else:
# --> 759         result = self._execute_without_timeout(task_prompt, task)
#     761 except TimeoutError as e:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:826, in Agent._execute_without_timeout(self, task_prompt, task)
#     822     raise RuntimeError("Agent executor is not initialized.")
#     824 result = cast(
#     825     dict[str, Any],
# --> 826     self.agent_executor.invoke(
#     827         {
#     828             "input": task_prompt,
#     829             "tool_names": self.agent_executor.tools_names,
#     830             "tools": self.agent_executor.tools_description,
#     831             "ask_for_human_input": task.human_input,
#     832         }
#     833     ),
#     834 )
#     835 return result["output"]
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:213, in CrewAgentExecutor.invoke(self, inputs)
#     212 try:
# --> 213     formatted_answer = self._invoke_loop()
#     214 except AssertionError:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:312, in CrewAgentExecutor._invoke_loop(self)
#     311 # Fall back to ReAct text-based pattern
# --> 312 return self._invoke_loop_react()
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:446, in CrewAgentExecutor._invoke_loop_react(self)
#     445     handle_unknown_error(PRINTER, e, verbose=self.agent.verbose)
# --> 446     raise e
#     447 finally:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:341, in CrewAgentExecutor._invoke_loop_react(self)
#     339 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 341 answer = get_llm_response(
#     342     llm=cast("BaseLLM", self.llm),
#     343     messages=self.messages,
#     344     callbacks=self.callbacks,
#     345     printer=PRINTER,
#     346     from_task=self.task,
#     347     from_agent=self.agent,
#     348     response_model=self.response_model,
#     349     executor_context=self,
#     350     verbose=self.agent.verbose,
#     351 )
#     352 # breakpoint()
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/utilities/agent_utils.py:475, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     474 except Exception as e:
# --> 475     raise e
#     477 return _validate_and_finalize_llm_response(
#     478     answer, executor_context, printer, verbose=verbose
#     479 )
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/utilities/agent_utils.py:465, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     464 try:
# --> 465     answer = llm.call(
#     466         messages,
#     467         tools=tools,
#     468         callbacks=callbacks,
#     469         available_functions=available_functions,
#     470         from_task=from_task,
#     471         from_agent=from_agent,
#     472         response_model=response_model,
#     473     )
#     474 except Exception as e:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/llms/providers/gemini/completion.py:314, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     305         return self._handle_streaming_completion(
#     306             formatted_content,
#     307             config,
#    (...)    311             effective_response_model,
#     312         )
# --> 314     return self._handle_completion(
#     315         formatted_content,
#     316         config,
#     317         available_functions,
#     318         from_task,
#     319         from_agent,
#     320         effective_response_model,
#     321     )
#     323 except APIError as e:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/llms/providers/gemini/completion.py:1126, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1125         raise LLMContextLengthExceededError(str(e)) from e
# -> 1126     raise e from e
#    1128 self._track_token_usage_internal(usage)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/llms/providers/gemini/completion.py:1115, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1114 contents_for_api: Any = contents
# -> 1115 response = self._client.models.generate_content(
#    1116     model=self.model,
#    1117     contents=contents_for_api,
#    1118     config=config,
#    1119 )
#    1121 usage = self._extract_token_usage(response)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/models.py:5644, in Models.generate_content(self, model, contents, config)
#    5643 i += 1
# -> 5644 response = self._generate_content(
#    5645     model=model, contents=contents, config=parsed_config
#    5646 )
#    5648 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/models.py:4306, in Models._generate_content(self, model, contents, config)
#    4304 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4306 response = self._api_client.request(
#    4307     'post', path, request_dict, http_options
#    4308 )
#    4310 if config is not None and getattr(
#    4311     config, 'should_return_http_response', None
#    4312 ):
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1398 http_request = self._build_request(
#    1399     http_method, path, request_dict, http_options
#    1400 )
# -> 1401 response = self._request(http_request, http_options, stream=False)
#    1402 response_body = (
#    1403     response.response_stream[0] if response.response_stream else ''
#    1404 )
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1237, in BaseApiClient._request(self, http_request, http_options, stream)
#    1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1237 return self._retry(self._request_once, http_request, stream)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1207 response = self._httpx_client.request(
#    1208     method=http_request.method,
#    1209     url=http_request.url,
#    (...)   1212     timeout=http_request.timeout,
#    1213 )
# -> 1214 errors.APIError.raise_for_response(response)
#    1215 return HttpResponse(
#    1216     response.headers, response if stream else [response.text]
#    1217 )
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 36.999677989s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '36s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# Cell In[47], line 7
#       5 )
#       6
# ----> 7 crew.kickoff(inputs={"topic": "The future of electrical vehicles"})
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/crew.py:903, in Crew.kickoff(self, inputs, input_files)
#     902 if self.process == Process.sequential:
# --> 903     result = self._run_sequential_process()
#     904 elif self.process == Process.hierarchical:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/crew.py:1334, in Crew._run_sequential_process(self)
#    1333 """Executes tasks sequentially and returns the final output."""
# -> 1334 return self._execute_tasks(self.tasks)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/crew.py:1431, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1430 context = self._get_context(task, task_outputs)
# -> 1431 task_output = task.execute_sync(
#    1432     agent=exec_data.agent,
#    1433     context=context,
#    1434     tools=exec_data.tools,
#    1435 )
#    1436 task_outputs.append(task_output)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/task.py:520, in Task.execute_sync(self, agent, context, tools)
#     519 self.start_time = datetime.datetime.now()
# --> 520 return self._execute_core(agent, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/task.py:817, in Task._execute_core(self, agent, context, tools)
#     816     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 817     raise e  # Re-raise the exception after emitting the event
#     818 finally:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/task.py:724, in Task._execute_core(self, agent, context, tools)
#     721     crewai_event_bus.emit(
#     722         self, TaskStartedEvent(context=context, task=self)
#     723     )
# --> 724 result = agent.execute_task(
#     725     task=self,
#     726     context=context,
#     727     tools=tools,
#     728 )
#     730 self._post_agent_execution(agent)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:772, in Agent.execute_task(self, task, context, tools)
#     771 except Exception as e:
# --> 772     result = self._handle_execution_error(e, task, context, tools)
#     774 return self._finalize_task_execution(task, result)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:682, in Agent._handle_execution_error(self, e, task, context, tools)
#     681 self._check_execution_error(e, task)
# --> 682 return self.execute_task(task, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:772, in Agent.execute_task(self, task, context, tools)
#     771 except Exception as e:
# --> 772     result = self._handle_execution_error(e, task, context, tools)
#     774 return self._finalize_task_execution(task, result)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:682, in Agent._handle_execution_error(self, e, task, context, tools)
#     681 self._check_execution_error(e, task)
# --> 682 return self.execute_task(task, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:772, in Agent.execute_task(self, task, context, tools)
#     771 except Exception as e:
# --> 772     result = self._handle_execution_error(e, task, context, tools)
#     774 return self._finalize_task_execution(task, result)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:681, in Agent._handle_execution_error(self, e, task, context, tools)
#     670 """Handle execution errors with retry logic (sync path).
#     671
#     672 Args:
#    (...)    679     Result from retried execution.
#     680 """
# --> 681 self._check_execution_error(e, task)
#     682 return self.execute_task(task, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:661, in Agent._check_execution_error(self, e, task)
#     653 crewai_event_bus.emit(
#     654     self,
#     655     event=AgentExecutionErrorEvent(
#    (...)    659     ),
#     660 )
# --> 661 raise e
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:759, in Agent.execute_task(self, task, context, tools)
#     758     else:
# --> 759         result = self._execute_without_timeout(task_prompt, task)
#     761 except TimeoutError as e:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:826, in Agent._execute_without_timeout(self, task_prompt, task)
#     822     raise RuntimeError("Agent executor is not initialized.")
#     824 result = cast(
#     825     dict[str, Any],
# --> 826     self.agent_executor.invoke(
#     827         {
#     828             "input": task_prompt,
#     829             "tool_names": self.agent_executor.tools_names,
#     830             "tools": self.agent_executor.tools_description,
#     831             "ask_for_human_input": task.human_input,
#     832         }
#     833     ),
#     834 )
#     835 return result["output"]
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:213, in CrewAgentExecutor.invoke(self, inputs)
#     212 try:
# --> 213     formatted_answer = self._invoke_loop()
#     214 except AssertionError:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:312, in CrewAgentExecutor._invoke_loop(self)
#     311 # Fall back to ReAct text-based pattern
# --> 312 return self._invoke_loop_react()
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:446, in CrewAgentExecutor._invoke_loop_react(self)
#     445     handle_unknown_error(PRINTER, e, verbose=self.agent.verbose)
# --> 446     raise e
#     447 finally:
#
# ...
#     663 def _handle_execution_error(
#     664     self,
#     665     e: Exception,
#    (...)    668     tools: list[BaseTool] | None,
#     669 ) -> Any:
#     670     """Handle execution errors with retry logic (sync path).
#     671
#     672     Args:
#    (...)    679         Result from retried execution.
#     680     """
# --> 681     self._check_execution_error(e, task)
#     682     return self.execute_task(task, context, tools)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:661, in Agent._check_execution_error(self, e, task)
#     652 if self._times_executed > self.max_retry_limit:
#     653     crewai_event_bus.emit(
#     654         self,
#     655         event=AgentExecutionErrorEvent(
#    (...)    659         ),
#     660     )
# --> 661     raise e
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:759, in Agent.execute_task(self, task, context, tools)
#     755         result = self._execute_with_timeout(
#     756             task_prompt, task, self.max_execution_time
#     757         )
#     758     else:
# --> 759         result = self._execute_without_timeout(task_prompt, task)
#     761 except TimeoutError as e:
#     762     crewai_event_bus.emit(
#     763         self,
#     764         event=AgentExecutionErrorEvent(
#    (...)    768         ),
#     769     )
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agent/core.py:826, in Agent._execute_without_timeout(self, task_prompt, task)
#     821 if not self.agent_executor:
#     822     raise RuntimeError("Agent executor is not initialized.")
#     824 result = cast(
#     825     dict[str, Any],
# --> 826     self.agent_executor.invoke(
#     827         {
#     828             "input": task_prompt,
#     829             "tool_names": self.agent_executor.tools_names,
#     830             "tools": self.agent_executor.tools_description,
#     831             "ask_for_human_input": task.human_input,
#     832         }
#     833     ),
#     834 )
#     835 return result["output"]
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:213, in CrewAgentExecutor.invoke(self, inputs)
#     210 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     212 try:
# --> 213     formatted_answer = self._invoke_loop()
#     214 except AssertionError:
#     215     if self.agent.verbose:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:312, in CrewAgentExecutor._invoke_loop(self)
#     309     return self._invoke_loop_native_tools()
#     311 # Fall back to ReAct text-based pattern
# --> 312 return self._invoke_loop_react()
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:446, in CrewAgentExecutor._invoke_loop_react(self)
#     444         continue
#     445     handle_unknown_error(PRINTER, e, verbose=self.agent.verbose)
# --> 446     raise e
#     447 finally:
#     448     self.iterations += 1
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/agents/crew_agent_executor.py:341, in CrewAgentExecutor._invoke_loop_react(self)
#     337     break
#     339 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 341 answer = get_llm_response(
#     342     llm=cast("BaseLLM", self.llm),
#     343     messages=self.messages,
#     344     callbacks=self.callbacks,
#     345     printer=PRINTER,
#     346     from_task=self.task,
#     347     from_agent=self.agent,
#     348     response_model=self.response_model,
#     349     executor_context=self,
#     350     verbose=self.agent.verbose,
#     351 )
#     352 # breakpoint()
#     353 if self.response_model is not None:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/utilities/agent_utils.py:475, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     465     answer = llm.call(
#     466         messages,
#     467         tools=tools,
#    (...)    472         response_model=response_model,
#     473     )
#     474 except Exception as e:
# --> 475     raise e
#     477 return _validate_and_finalize_llm_response(
#     478     answer, executor_context, printer, verbose=verbose
#     479 )
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/utilities/agent_utils.py:465, in get_llm_response(llm, messages, callbacks, printer, tools, available_functions, from_task, from_agent, response_model, executor_context, verbose)
#     462 messages = _prepare_llm_call(executor_context, messages, printer, verbose=verbose)
#     464 try:
# --> 465     answer = llm.call(
#     466         messages,
#     467         tools=tools,
#     468         callbacks=callbacks,
#     469         available_functions=available_functions,
#     470         from_task=from_task,
#     471         from_agent=from_agent,
#     472         response_model=response_model,
#     473     )
#     474 except Exception as e:
#     475     raise e
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/llms/providers/gemini/completion.py:314, in GeminiCompletion.call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     304     if self.stream:
#     305         return self._handle_streaming_completion(
#     306             formatted_content,
#     307             config,
#    (...)    311             effective_response_model,
#     312         )
# --> 314     return self._handle_completion(
#     315         formatted_content,
#     316         config,
#     317         available_functions,
#     318         from_task,
#     319         from_agent,
#     320         effective_response_model,
#     321     )
#     323 except APIError as e:
#     324     error_msg = f"Google Gemini API error: {e.code} - {e.message}"
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/llms/providers/gemini/completion.py:1126, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1124         logging.error(f"Context window exceeded: {e}")
#    1125         raise LLMContextLengthExceededError(str(e)) from e
# -> 1126     raise e from e
#    1128 self._track_token_usage_internal(usage)
#    1130 return self._process_response_with_tools(
#    1131     response=response,
#    1132     contents=contents,
#    (...)   1137     usage=usage,
#    1138 )
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/crewai/llms/providers/gemini/completion.py:1115, in GeminiCompletion._handle_completion(self, contents, config, available_functions, from_task, from_agent, response_model)
#    1112 try:
#    1113     # The API accepts list[Content] but mypy is overly strict about variance
#    1114     contents_for_api: Any = contents
# -> 1115     response = self._client.models.generate_content(
#    1116         model=self.model,
#    1117         contents=contents_for_api,
#    1118         config=config,
#    1119     )
#    1121     usage = self._extract_token_usage(response)
#    1122 except Exception as e:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/models.py:5644, in Models.generate_content(self, model, contents, config)
#    5642 while remaining_remote_calls_afc > 0:
#    5643   i += 1
# -> 5644   response = self._generate_content(
#    5645       model=model, contents=contents, config=parsed_config
#    5646   )
#    5648   function_map = _extra_utils.get_function_map(parsed_config)
#    5649   if not function_map:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/models.py:4306, in Models._generate_content(self, model, contents, config)
#    4303 request_dict = _common.convert_to_dict(request_dict)
#    4304 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4306 response = self._api_client.request(
#    4307     'post', path, request_dict, http_options
#    4308 )
#    4310 if config is not None and getattr(
#    4311     config, 'should_return_http_response', None
#    4312 ):
#    4313   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1401, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1391 def request(
#    1392     self,
#    1393     http_method: str,
#    (...)   1396     http_options: Optional[HttpOptionsOrDict] = None,
#    1397 ) -> SdkHttpResponse:
#    1398   http_request = self._build_request(
#    1399       http_method, path, request_dict, http_options
#    1400   )
# -> 1401   response = self._request(http_request, http_options, stream=False)
#    1402   response_body = (
#    1403       response.response_stream[0] if response.response_stream else ''
#    1404   )
#    1405   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1237, in BaseApiClient._request(self, http_request, http_options, stream)
#    1234     retry = tenacity.Retrying(**retry_kwargs)
#    1235     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1237 return self._retry(self._request_once, http_request, stream)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/anaconda3/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1214, in BaseApiClient._request_once(self, http_request, stream)
#    1206 else:
#    1207   response = self._httpx_client.request(
#    1208       method=http_request.method,
#    1209       url=http_request.url,
#    (...)   1212       timeout=http_request.timeout,
#    1213   )
# -> 1214   errors.APIError.raise_for_response(response)
#    1215   return HttpResponse(
#    1216       response.headers, response if stream else [response.text]
#    1217   )
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~/PycharmProjects/agentic_ai_project/.venv/lib/python3.12/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     145 """Raises an appropriate APIError subclass based on the status code.
#     146
#     147 Args:
#    (...)    156   APIError: For other error status codes.
#     157 """
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#     161   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 36.999677989s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '36s'}]}}
# ╭────────────────────────── Trace Batch Finalization ──────────────────────────╮
# │ ✅ Trace batch finalized with session ID:                                    │
# │ 69e2cd14-3f19-4730-a368-777fc5a958b4                                         │
# │                                                                              │
# │ 🔗 View here:                                                                │
# │ https://app.crewai.com/crewai_plus/ephemeral_trace_batches/69e2cd14-3f19-473 │
# │ 0-a368-777fc5a958b4?access_code=TRACE-6f3eca39f8                             │
# │ 🔑 Access Code: TRACE-6f3eca39f8                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: d9c1f621-96b4-4e31-b100-c5a4bc97dd74                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
